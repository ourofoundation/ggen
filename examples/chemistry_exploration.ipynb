# %% [markdown]
# # Chemistry Exploration with ggen
#
# This notebook demonstrates how to systematically explore a chemical space by:
# 1. Specifying a chemical system (e.g., "Li-Co-O")
# 2. Generating candidate structures across different stoichiometries
# 3. Storing all data in SQLite for persistence
# 4. Building a phase diagram to identify thermodynamically stable candidates

# %%
# %pip install -e ..
# Out:
# Obtaining file:///Users/mmoderwell/ouro/ggen
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.20.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (2.4.0)
# Requirement already satisfied: scipy>=1.7.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (1.16.0)
# Requirement already satisfied: pymatgen>=2023.0.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (2025.10.7)
# Requirement already satisfied: pyxtal>=0.5.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (1.0.9)
# Requirement already satisfied: ase>=3.22.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (3.24.0)
# Requirement already satisfied: requests>=2.25.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (2.32.3)
# Requirement already satisfied: orb-models>=0.1.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (0.5.4)
# Requirement already satisfied: matplotlib>=3.3.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ase>=3.22.0->ggen==0.1.0) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (2.9.0.post0)
# Requirement already satisfied: cached_path>=1.6.7 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from orb-models>=0.1.0->ggen==0.1.0) (1.7.3)
# Requirement already satisfied: torch<3.0.0,>=2.6.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from orb-models>=0.1.0->ggen==0.1.0) (2.7.1)
# Requirement already satisfied: dm-tree==0.1.8 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from orb-models>=0.1.0->ggen==0.1.0) (0.1.8)
# Requirement already satisfied: tqdm>=4.66.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from orb-models>=0.1.0->ggen==0.1.0) (4.67.1)
# Requirement already satisfied: filelock in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (4.14.1)
# Requirement already satisfied: setuptools in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (75.6.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (3.1.4)
# Requirement already satisfied: fsspec in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (2024.10.0)
# Requirement already satisfied: rich<14.0,>=12.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (13.9.4)
# Requirement already satisfied: boto3<2.0,>=1.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.39.3)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.19.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.8.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (0.33.2)
# Requirement already satisfied: botocore<1.40.0,>=1.39.3 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from boto3<2.0,>=1.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.39.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from boto3<2.0,>=1.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from boto3<2.0,>=1.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (0.13.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from botocore<1.40.0,>=1.39.3->boto3<2.0,>=1.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.3.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.40.3)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.25.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (5.29.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (4.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.8.1->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (6.0.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.8.1->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.1.5)
# Requirement already satisfied: six>=1.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from requests>=2.25.0->ggen==0.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from requests>=2.25.0->ggen==0.1.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from requests>=2.25.0->ggen==0.1.0) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from rich<14.0,>=12.1->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from rich<14.0,>=12.1->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.18.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (0.6.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.1->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (0.1.2)
# Requirement already satisfied: bibtexparser>=1.4.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (1.4.3)
# Requirement already satisfied: joblib>=1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (1.4.2)
# Requirement already satisfied: monty>=2025.1.9 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (2025.1.9)
# Requirement already satisfied: orjson<4,>=3.10 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (3.10.18)
# Requirement already satisfied: palettable>=3.3.3 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (3.3.3)
# Requirement already satisfied: pandas>=2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (2.3.1)
# Requirement already satisfied: plotly>=5.0.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (6.5.0)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (0.18.10)
# Requirement already satisfied: spglib>=2.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (2.5.0)
# Requirement already satisfied: tabulate>=0.9 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (0.9.0)
# Requirement already satisfied: uncertainties>=3.1.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (3.2.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pandas>=2->pymatgen>=2023.0.0->ggen==0.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pandas>=2->pymatgen>=2023.0.0->ggen==0.1.0) (2024.2)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from plotly>=5.0.0->pymatgen>=2023.0.0->ggen==0.1.0) (2.14.0)
# Requirement already satisfied: vasprun-xml>=1.0.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyxtal>=0.5.0->ggen==0.1.0) (1.0.4)
# Requirement already satisfied: importlib_metadata>=1.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyxtal>=0.5.0->ggen==0.1.0) (8.7.0)
# Requirement already satisfied: pyocse>=0.1.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyxtal>=0.5.0->ggen==0.1.0) (0.1.2)
# Requirement already satisfied: psutil in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyxtal>=0.5.0->ggen==0.1.0) (6.1.0)
# Requirement already satisfied: zipp>=3.20 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from importlib_metadata>=1.4->pyxtal>=0.5.0->ggen==0.1.0) (3.23.0)
# Requirement already satisfied: toml in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyocse>=0.1.1->pyxtal>=0.5.0->ggen==0.1.0) (0.10.2)
# Requirement already satisfied: xmltodict in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyocse>=0.1.1->pyxtal>=0.5.0->ggen==0.1.0) (0.14.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ruamel.yaml>=0.17.0->pymatgen>=2023.0.0->ggen==0.1.0) (0.2.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (1.3.0)
# Requirement already satisfied: lxml>=4.2.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from vasprun-xml>=1.0.4->pyxtal>=0.5.0->ggen==0.1.0) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from jinja2->torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (3.0.2)
# Building wheels for collected packages: ggen
#   Building editable for ggen (pyproject.toml) ... done
#   Created wheel for ggen: filename=ggen-0.1.0-0.editable-py3-none-any.whl size=7756 sha256=dcd8981fb456882e179dc6c326d4600a646a8cd1804c517d00d00d019110e505
#   Stored in directory: /private/var/folders/zw/zcpqh2ss43v0d8_8mdqcds440000gn/T/pip-ephem-wheel-cache-9b4dpuru/wheels/ac/6f/ca/e5e77e53988e12825fc0b1323c5ae56703f9c5eab46d137fdd
# Successfully built ggen
# Installing collected packages: ggen
#   Attempting uninstall: ggen
#     Found existing installation: ggen 0.1.0
#     Uninstalling ggen-0.1.0:
#       Successfully uninstalled ggen-0.1.0
# Successfully installed ggen-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
logging.basicConfig(level=logging.INFO)

# %%
from ggen import ChemistryExplorer

# %% [markdown]
# ## Initialize the Explorer
#
# Create a `ChemistryExplorer` instance. You can optionally specify:
# - `calculator`: Custom ASE calculator (defaults to ORB)
# - `random_seed`: For reproducibility
# - `output_dir`: Where to store results

# %%
explorer = ChemistryExplorer(
    random_seed=42,
    output_dir="./exploration_runs"
)

# %% [markdown]
# ## Preview Stoichiometries
#
# Before running the full exploration, you can preview what stoichiometries will be generated:

# %%
# Parse the chemical system
elements = explorer.parse_chemical_system("Fe-Mn-Bi")
print(f"Elements: {elements}")

# Enumerate stoichiometries
stoichiometries = explorer.enumerate_stoichiometries(
    elements=elements,
    max_atoms=8,
    min_atoms=2,
    include_binaries=True,
    include_ternaries=True,
)

print(f"\nTotal stoichiometries: {len(stoichiometries)}")
print("\nFirst 10:")
for s in stoichiometries[:10]:
    formula = "".join(f"{el}{c if c > 1 else ''}" for el, c in sorted(s.items()))
    print(f"  {formula}: {s}")
# Out:
# Elements: ['Bi', 'Fe', 'Mn']
#
# Total stoichiometries: 115
#
# First 10:
#   BiFe: {'Bi': 1, 'Fe': 1}
#   BiFe2: {'Bi': 1, 'Fe': 2}
#   Bi2Fe: {'Bi': 2, 'Fe': 1}
#   BiFe3: {'Bi': 1, 'Fe': 3}
#   Bi3Fe: {'Bi': 3, 'Fe': 1}
#   BiFe4: {'Bi': 1, 'Fe': 4}
#   Bi2Fe3: {'Bi': 2, 'Fe': 3}
#   Bi3Fe2: {'Bi': 3, 'Fe': 2}
#   Bi4Fe: {'Bi': 4, 'Fe': 1}
#   BiFe5: {'Bi': 1, 'Fe': 5}

# %% [markdown]
# ## Run the Exploration
#
# Now let's run the full exploration. This will:
# 1. Generate structures for each stoichiometry
# 2. Optimize them using the ORB calculator
# 3. Store results in SQLite + CIF files
# 4. Build a phase diagram

# %%
# Run a smaller exploration for demonstration
# In practice, you'd want larger max_atoms and more trials

result = explorer.explore(
    chemical_system="Fe-Mn-Co",
    max_atoms=20,          
    min_atoms=2,
    num_trials=15,          # Trials per stoichiometry
    optimize=True,
    include_binaries=True,
    include_ternaries=True,
    max_stoichiometries=100,
    crystal_systems=["hexagonal", "tetragonal"],
    load_previous_runs=True,      # Load from all previous runs
    skip_existing_formulas=False,  # Skip formulas we already have
)
# Out:
# INFO:ggen.explorer:Starting exploration of Co-Fe-Mn
# INFO:ggen.explorer:Found 5 previous runs for Co-Fe-Mn
# INFO:ggen.explorer:Loaded 0 candidates from exploration_Co-Fe-Mn_20260102_165713
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/core/structure.py:3109: UserWarning: Issues encountered while parsing CIF: 2 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/core/structure.py:3109: UserWarning: Issues encountered while parsing CIF: 4 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/core/structure.py:3109: UserWarning: Issues encountered while parsing CIF: 24 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/core/structure.py:3109: UserWarning: Issues encountered while parsing CIF: 1 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/core/structure.py:3109: UserWarning: Issues encountered while parsing CIF: 6 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/io/cif.py:1314: UserWarning: Incorrect stoichiometry:
#   CIF={'Mn': 4.0, 'Fe': 6.0, 'Co': 10.0}
#   PMG={'Mn': 8.0, 'Fe': 16.0, 'Co': 24.0}
#   ratios={'Fe': 2.6666666666666665, 'Mn': 2.0, 'Co': 2.4}
#   if struct := self._get_structure(data, primitive, symmetrized, check_occu=check_occu):
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/core/structure.py:3109: UserWarning: Issues encountered while parsing CIF: 8 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/core/structure.py:3109: UserWarning: Issues encountered while parsing CIF: 16 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# INFO:ggen.explorer:Loaded 161 candidates from exploration_Co-Fe-Mn_20260102_160815
# INFO:ggen.explorer:Loaded 65 candidates from exploration_Co-Fe-Mn_20260102_153726
# INFO:ggen.explorer:Loaded 65 candidates from exploration_Co-Fe-Mn_20260102_150142
# INFO:ggen.explorer:Loaded 53 candidates from exploration_Co-Fe-Mn_20260102_134831
# INFO:ggen.explorer:Loaded 161 unique structures from previous runs
# INFO:ggen.explorer:Exploring 100 stoichiometries
# INFO:ggen.explorer:[1/100] Generating Co2Fe7Mn4
# INFO:ggen.explorer:Generating structure for Co2Fe7Mn4
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co2Fe7Mn4 (elements=['Co', 'Fe', 'Mn'], counts=[2, 7, 4])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-80.5477 eV, score=-99.3877
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 400 steps, final energy=-97.9095 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (13 -> 13 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 100 steps, energy=-97.8486 eV
# INFO:ggen.ggen:Symmetry refinement successful: P6mm (#183)
# INFO:ggen.ggen:Crystal generation complete: Co2Fe7Mn4, SG=P6mm (#183), energy=-97.8486 eV
# INFO:ggen.explorer:[2/100] Generating Co3Fe5Mn12
# INFO:ggen.explorer:Generating structure for Co3Fe5Mn12
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co3Fe5Mn12 (elements=['Co', 'Fe', 'Mn'], counts=[3, 5, 12])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 175, energy=-142.0156 eV, score=-159.4556
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 113 steps, final energy=-169.5000 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (20 -> 20 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 16 steps, energy=-169.5000 eV
# INFO:ggen.ggen:Symmetry refinement successful: P6mm (#183)
# INFO:ggen.ggen:Crystal generation complete: Co3Fe5Mn12, SG=P6mm (#183), energy=-169.5000 eV
# INFO:ggen.explorer:[3/100] Generating Co3Fe7Mn7
# INFO:ggen.explorer:Generating structure for Co3Fe7Mn7
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co3Fe7Mn7 (elements=['Co', 'Fe', 'Mn'], counts=[3, 7, 7])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 123, energy=-119.9438 eV, score=-132.1638
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 73 steps, final energy=-141.9057 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (17 -> 17 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 1 steps, energy=-141.9057 eV
# INFO:ggen.ggen:Symmetry refinement successful: P4/mmm (#123)
# INFO:ggen.ggen:Crystal generation complete: Co3Fe7Mn7, SG=P4/mmm (#123), energy=-141.9057 eV
# INFO:ggen.explorer:[4/100] Generating Co5Fe7Mn
# INFO:ggen.explorer:Generating structure for Co5Fe7Mn
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co5Fe7Mn (elements=['Co', 'Fe', 'Mn'], counts=[5, 7, 1])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 175, energy=-75.3055 eV, score=-92.7555
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 210 steps, final energy=-103.7013 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (13 -> 39 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 0 steps, energy=-311.1043 eV
# INFO:ggen.ggen:Symmetry refinement successful: R3m (#160)
# INFO:ggen.ggen:Crystal generation complete: Co5Fe7Mn, SG=R3m (#160), energy=-311.1043 eV
# INFO:ggen.explorer:[5/100] Generating Co2Fe2Mn9
# INFO:ggen.explorer:Generating structure for Co2Fe2Mn9
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co2Fe2Mn9 (elements=['Co', 'Fe', 'Mn'], counts=[2, 2, 9])
# INFO:ggen.ggen:Found 32 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-94.7002 eV, score=-113.5402
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 400 steps, final energy=-103.0377 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (13 -> 26 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 100 steps, energy=-206.2824 eV
# INFO:ggen.ggen:Symmetry refinement successful: Cm (#8)
# INFO:ggen.ggen:Crystal generation complete: Co2Fe2Mn9, SG=Cm (#8), energy=-206.2824 eV
# INFO:ggen.explorer:[6/100] Generating Co4Fe11Mn3
# INFO:ggen.explorer:Generating structure for Co4Fe11Mn3
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co4Fe11Mn3 (elements=['Co', 'Fe', 'Mn'], counts=[4, 11, 3])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 115, energy=-108.8397 eV, score=-120.2397
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 156 steps, final energy=-148.3083 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (18 -> 36 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 1 steps, energy=-296.6192 eV
# INFO:ggen.ggen:Symmetry refinement successful: Amm2 (#38)
# INFO:ggen.ggen:Crystal generation complete: Co4Fe11Mn3, SG=Amm2 (#38), energy=-296.6192 eV
# INFO:ggen.explorer:[7/100] Generating CoMn16
# INFO:ggen.explorer:Generating structure for CoMn16
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for CoMn16 (elements=['Co', 'Mn'], counts=[1, 16])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 75, energy=-127.6360 eV, score=-135.0860
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 400 steps, final energy=-151.8372 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: CoMn16, SG=P1 (#1), energy=-151.8372 eV
# INFO:ggen.explorer:[8/100] Generating CoFe5Mn3
# INFO:ggen.explorer:Generating structure for CoFe5Mn3
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for CoFe5Mn3 (elements=['Co', 'Fe', 'Mn'], counts=[1, 5, 3])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-61.8948 eV, score=-80.7548
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 329 steps, final energy=-76.2001 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: CoFe5Mn3, SG=P1 (#1), energy=-76.2001 eV
# INFO:ggen.explorer:[9/100] Generating Co12Mn5
# INFO:ggen.explorer:Generating structure for Co12Mn5
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co12Mn5 (elements=['Co', 'Mn'], counts=[12, 5])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-102.3229 eV, score=-121.1529
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 400 steps, final energy=-128.1039 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (17 -> 17 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 12 steps, energy=-128.1061 eV
# INFO:ggen.ggen:Symmetry refinement successful: P3m1 (#156)
# INFO:ggen.ggen:Crystal generation complete: Co12Mn5, SG=P3m1 (#156), energy=-128.1061 eV
# INFO:ggen.explorer:[10/100] Generating Co4Fe12Mn
# INFO:ggen.explorer:Generating structure for Co4Fe12Mn
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co4Fe12Mn (elements=['Co', 'Fe', 'Mn'], counts=[4, 12, 1])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 75, energy=-102.4584 eV, score=-109.8684
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 245 steps, final energy=-136.6434 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (17 -> 34 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 2 steps, energy=-273.2991 eV
# INFO:ggen.ggen:Symmetry refinement successful: Cm (#8)
# INFO:ggen.ggen:Crystal generation complete: Co4Fe12Mn, SG=Cm (#8), energy=-273.2991 eV
# INFO:ggen.explorer:[11/100] Generating Co10Mn9
# INFO:ggen.explorer:Generating structure for Co10Mn9
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co10Mn9 (elements=['Co', 'Mn'], counts=[10, 9])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 75, energy=-117.7644 eV, score=-125.1744
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 204 steps, final energy=-150.9564 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: Co10Mn9, SG=P1 (#1), energy=-150.9564 eV
# INFO:ggen.explorer:[12/100] Generating Co3Fe3Mn8
# INFO:ggen.explorer:Generating structure for Co3Fe3Mn8
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co3Fe3Mn8 (elements=['Co', 'Fe', 'Mn'], counts=[3, 3, 8])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 175, energy=-94.9435 eV, score=-112.3935
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 168 steps, final energy=-119.1349 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (14 -> 28 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 2 steps, energy=-238.2670 eV
# INFO:ggen.ggen:Symmetry refinement successful: Cm (#8)
# INFO:ggen.ggen:Crystal generation complete: Co3Fe3Mn8, SG=Cm (#8), energy=-238.2670 eV
# INFO:ggen.explorer:[13/100] Generating Co3Fe8Mn
# INFO:ggen.explorer:Generating structure for Co3Fe8Mn
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co3Fe8Mn (elements=['Co', 'Fe', 'Mn'], counts=[3, 8, 1])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 75, energy=-73.3337 eV, score=-80.7637
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 400 steps, final energy=-90.8916 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: Co3Fe8Mn, SG=P1 (#1), energy=-90.8916 eV
# INFO:ggen.explorer:[14/100] Generating Co10Fe5Mn3
# INFO:ggen.explorer:Generating structure for Co10Fe5Mn3
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co10Fe5Mn3 (elements=['Co', 'Fe', 'Mn'], counts=[10, 5, 3])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 175, energy=-94.0268 eV, score=-111.4668
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 209 steps, final energy=-140.0715 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: Co10Fe5Mn3, SG=P1 (#1), energy=-140.0715 eV
# INFO:ggen.explorer:[15/100] Generating CoFe9Mn
# INFO:ggen.explorer:Generating structure for CoFe9Mn
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for CoFe9Mn (elements=['Co', 'Fe', 'Mn'], counts=[1, 9, 1])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-76.8719 eV, score=-95.7319
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 114 steps, final energy=-90.4780 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: CoFe9Mn, SG=P1 (#1), energy=-90.4780 eV
# INFO:ggen.explorer:[16/100] Generating Co2Fe8Mn7
# INFO:ggen.explorer:Generating structure for Co2Fe8Mn7
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co2Fe8Mn7 (elements=['Co', 'Fe', 'Mn'], counts=[2, 8, 7])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 75, energy=-103.6811 eV, score=-111.1111
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 400 steps, final energy=-143.4550 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: Co2Fe8Mn7, SG=P1 (#1), energy=-143.4550 eV
# INFO:ggen.explorer:[17/100] Generating Co3Fe13Mn3
# INFO:ggen.explorer:Generating structure for Co3Fe13Mn3
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co3Fe13Mn3 (elements=['Co', 'Fe', 'Mn'], counts=[3, 13, 3])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-130.1334 eV, score=-148.9734
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 146 steps, final energy=-154.5377 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: Co3Fe13Mn3, SG=P1 (#1), energy=-154.5377 eV
# INFO:ggen.explorer:[18/100] Generating FeMn4
# INFO:ggen.explorer:Generating structure for FeMn4
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for FeMn4 (elements=['Fe', 'Mn'], counts=[1, 4])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-38.6544 eV, score=-57.5244
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 82 steps, final energy=-43.1931 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (5 -> 10 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 4 steps, energy=-86.3856 eV
# INFO:ggen.ggen:Symmetry refinement successful: Amm2 (#38)
# INFO:ggen.ggen:Crystal generation complete: FeMn4, SG=Amm2 (#38), energy=-86.3856 eV
# INFO:ggen.explorer:[19/100] Generating Co5Fe11Mn3
# INFO:ggen.explorer:Generating structure for Co5Fe11Mn3
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co5Fe11Mn3 (elements=['Co', 'Fe', 'Mn'], counts=[5, 11, 3])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 115, energy=-121.1501 eV, score=-132.5801
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 400 steps, final energy=-142.9124 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (19 -> 19 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 100 steps, energy=-152.0814 eV
# INFO:ggen.ggen:Symmetry refinement successful: Pm (#6)
# INFO:ggen.ggen:Crystal generation complete: Co5Fe11Mn3, SG=P1 (#1), energy=-152.0814 eV
# INFO:ggen.explorer:[20/100] Generating Co5Fe2Mn13
# INFO:ggen.explorer:Generating structure for Co5Fe2Mn13
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co5Fe2Mn13 (elements=['Co', 'Fe', 'Mn'], counts=[5, 2, 13])
# INFO:ggen.ggen:Found 32 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-126.6255 eV, score=-145.4755
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 329 steps, final energy=-168.5812 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: Co5Fe2Mn13, SG=P1 (#1), energy=-168.5812 eV
# INFO:ggen.explorer:[21/100] Generating Fe7Mn5
# INFO:ggen.explorer:Generating structure for Fe7Mn5
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Fe7Mn5 (elements=['Fe', 'Mn'], counts=[7, 5])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-81.0882 eV, score=-99.9382
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 400 steps, final energy=-82.7914 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: Fe7Mn5, SG=P1 (#1), energy=-82.7914 eV
# INFO:ggen.explorer:[22/100] Generating Co13Fe5Mn
# INFO:ggen.explorer:Generating structure for Co13Fe5Mn
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co13Fe5Mn (elements=['Co', 'Fe', 'Mn'], counts=[13, 5, 1])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# ...
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-111.3573 eV, score=-130.2173
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 400 steps, final energy=-132.6482 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: Co14Fe5, SG=P1 (#1), energy=-132.6482 eV
# INFO:ggen.explorer:Using better structure from previous run for Co14Fe5 (prev=-7.4241 vs new=-6.9815 eV/atom)
# INFO:ggen.explorer:[98/100] Generating Co7Fe4Mn4
# INFO:ggen.explorer:Generating structure for Co7Fe4Mn4
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co7Fe4Mn4 (elements=['Co', 'Fe', 'Mn'], counts=[7, 4, 4])
# INFO:ggen.ggen:Found 32 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-95.3675 eV, score=-114.2075
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 207 steps, final energy=-119.3065 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (15 -> 15 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 2 steps, energy=-119.3065 eV
# INFO:ggen.ggen:Symmetry refinement successful: P31m (#157)
# INFO:ggen.ggen:Crystal generation complete: Co7Fe4Mn4, SG=P31m (#157), energy=-119.3065 eV
# INFO:ggen.explorer:[99/100] Generating CoFe8Mn4
# INFO:ggen.explorer:Generating structure for CoFe8Mn4
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for CoFe8Mn4 (elements=['Co', 'Fe', 'Mn'], counts=[1, 8, 4])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 175, energy=-83.8916 eV, score=-101.3516
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 263 steps, final energy=-108.8119 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:Re-relaxing after symmetry refinement (13 -> 39 atoms)...
# INFO:ggen.ggen:Post-refinement relaxation: 0 steps, energy=-326.4359 eV
# INFO:ggen.ggen:Symmetry refinement successful: R3m (#160)
# INFO:ggen.ggen:Crystal generation complete: CoFe8Mn4, SG=R3m (#160), energy=-326.4359 eV
# INFO:ggen.explorer:Using better structure from previous run for CoFe8Mn4 (prev=-8.4283 vs new=-8.3702 eV/atom)
# INFO:ggen.explorer:[100/100] Generating Co3Fe9Mn7
# INFO:ggen.explorer:Generating structure for Co3Fe9Mn7
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Co3Fe9Mn7 (elements=['Co', 'Fe', 'Mn'], counts=[3, 9, 7])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 189, 175, 115, 123]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 123, energy=-130.7489 eV, score=-142.9789
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization...
# INFO:ggen.ggen:Optimization complete: 400 steps, final energy=-149.3971 eV
# INFO:ggen.ggen:Attempting post-relaxation symmetry refinement...
# INFO:ggen.ggen:No higher symmetry detected after relaxation
# INFO:ggen.ggen:Crystal generation complete: Co3Fe9Mn7, SG=P1 (#1), energy=-149.3971 eV
# INFO:ggen.explorer:Including Co10Fe3Mn4 from previous run (E=-7.5509 eV/atom)
# INFO:ggen.explorer:Including Co8Mn from previous run (E=-6.8760 eV/atom)
# INFO:ggen.explorer:Including Co4Fe3Mn13 from previous run (E=-8.4838 eV/atom)
# INFO:ggen.explorer:Including CoFe9Mn8 from previous run (E=-8.4614 eV/atom)
# INFO:ggen.explorer:Including Co9Fe5Mn3 from previous run (E=-7.7564 eV/atom)
# INFO:ggen.explorer:Including Fe6Mn5 from previous run (E=-8.6506 eV/atom)
# INFO:ggen.explorer:Including CoFe11Mn from previous run (E=-8.3942 eV/atom)
# INFO:ggen.explorer:Including Co3Fe8Mn5 from previous run (E=-8.3682 eV/atom)
# INFO:ggen.explorer:Including Co3FeMn9 from previous run (E=-8.5649 eV/atom)
# INFO:ggen.explorer:Including Co5Fe14Mn from previous run (E=-7.1838 eV/atom)
# INFO:ggen.explorer:Including Co5Fe4Mn4 from previous run (E=-7.9521 eV/atom)
# INFO:ggen.explorer:Including Co5Fe10Mn3 from previous run (E=-8.0604 eV/atom)
# INFO:ggen.explorer:Including Co5Fe9Mn3 from previous run (E=-8.0568 eV/atom)
# INFO:ggen.explorer:Including Fe13Mn3 from previous run (E=-8.4214 eV/atom)
# INFO:ggen.explorer:Including CoFe6Mn10 from previous run (E=-8.6240 eV/atom)
# INFO:ggen.explorer:Including Co4Fe3 from previous run (E=-7.6322 eV/atom)
# INFO:ggen.explorer:Including Co10FeMn2 from previous run (E=-7.3603 eV/atom)
# INFO:ggen.explorer:Including CoFe11 from previous run (E=-8.3460 eV/atom)
# INFO:ggen.explorer:Including Co3Mn10 from previous run (E=-8.5029 eV/atom)
# INFO:ggen.explorer:Including Co11Fe8 from previous run (E=-7.5788 eV/atom)
# INFO:ggen.explorer:Including Co9Fe5 from previous run (E=-6.7512 eV/atom)
# INFO:ggen.explorer:Including Co2Fe5Mn5 from previous run (E=-8.3863 eV/atom)
# INFO:ggen.explorer:Including Co3Fe2Mn8 from previous run (E=-8.3542 eV/atom)
# INFO:ggen.explorer:Including Fe14Mn3 from previous run (E=-8.3516 eV/atom)
# INFO:ggen.explorer:Including Fe11Mn5 from previous run (E=-8.6209 eV/atom)
# INFO:ggen.explorer:Including Co8Fe4Mn from previous run (E=-7.3416 eV/atom)
# INFO:ggen.explorer:Including Fe2Mn5 from previous run (E=-8.8929 eV/atom)
# INFO:ggen.explorer:Including Co8Fe3Mn from previous run (E=-7.5579 eV/atom)
# INFO:ggen.explorer:Including CoFe5Mn9 from previous run (E=-8.7213 eV/atom)
# INFO:ggen.explorer:Including CoFe16Mn2 from previous run (E=-8.2405 eV/atom)
# INFO:ggen.explorer:Including Co9Fe3Mn8 from previous run (E=-7.5366 eV/atom)
# INFO:ggen.explorer:Including Co7Fe9Mn2 from previous run (E=-7.8014 eV/atom)
# INFO:ggen.explorer:Including CoFeMn17 from previous run (E=-8.8625 eV/atom)
# INFO:ggen.explorer:Including Co9Fe2Mn4 from previous run (E=-7.7671 eV/atom)
# INFO:ggen.explorer:Including Co15Fe2 from previous run (E=-7.2384 eV/atom)
# INFO:ggen.explorer:Including Fe7Mn from previous run (E=-8.4558 eV/atom)
# INFO:ggen.explorer:Including Co11Fe3Mn5 from previous run (E=-7.7962 eV/atom)
# INFO:ggen.explorer:Including Fe8Mn5 from previous run (E=-8.0419 eV/atom)
# INFO:ggen.explorer:Including Co2Fe3Mn6 from previous run (E=-7.8905 eV/atom)
# INFO:ggen.explorer:Including Co7Fe3 from previous run (E=-6.7061 eV/atom)
# INFO:ggen.explorer:Including Co2FeMn16 from previous run (E=-8.7183 eV/atom)
# INFO:ggen.explorer:Including Co3Fe10Mn4 from previous run (E=-8.1626 eV/atom)
# INFO:ggen.explorer:Including Co8Fe3Mn6 from previous run (E=-7.9534 eV/atom)
# INFO:ggen.explorer:Including Co3Fe11Mn4 from previous run (E=-8.3366 eV/atom)
# INFO:ggen.explorer:Including Co14Fe4Mn from previous run (E=-7.3648 eV/atom)
# INFO:ggen.explorer:Including Co2Fe5Mn3 from previous run (E=-8.3270 eV/atom)
# INFO:ggen.explorer:Including Co13Fe5Mn2 from previous run (E=-7.5727 eV/atom)
# INFO:ggen.explorer:Including Co7FeMn6 from previous run (E=-7.9779 eV/atom)
# INFO:ggen.explorer:Including Co11Fe2Mn6 from previous run (E=-7.7675 eV/atom)
# INFO:ggen.explorer:Including Co9Fe10 from previous run (E=-7.8325 eV/atom)
# INFO:ggen.explorer:Including Co4Fe11Mn5 from previous run (E=-8.2816 eV/atom)
# INFO:ggen.explorer:Including Co13Fe2Mn from previous run (E=-7.3504 eV/atom)
# INFO:ggen.explorer:Including Co9Fe6Mn2 from previous run (E=-7.6600 eV/atom)
# INFO:ggen.explorer:Including CoFe13Mn4 from previous run (E=-8.4915 eV/atom)
# INFO:ggen.explorer:Including Co4Fe13 from previous run (E=-7.8879 eV/atom)
# INFO:ggen.explorer:Including Co5Fe11Mn2 from previous run (E=-7.9485 eV/atom)
# INFO:ggen.explorer:Including Co8Fe5Mn7 from previous run (E=-8.1582 eV/atom)
# INFO:ggen.explorer:Including Co16Fe3Mn from previous run (E=-7.3653 eV/atom)
# INFO:ggen.explorer:Including Co3Fe4Mn10 from previous run (E=-8.4094 eV/atom)
# INFO:ggen.explorer:Including Co10Fe3Mn3 from previous run (E=-7.5299 eV/atom)
# INFO:ggen.explorer:Including Co15Fe3Mn2 from previous run (E=-7.4381 eV/atom)
# INFO:ggen.explorer:Including Co5Fe3Mn2 from previous run (E=-6.6072 eV/atom)
# ---------------------------------------------------------------------------
# SymmetryUndeterminedError                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 # Run a smaller exploration for demonstration
#       2 # In practice, you'd want larger max_atoms and more trials
# ----> 4 result = explorer.explore(
#       5     chemical_system="Fe-Mn-Co",
#       6     max_atoms=20,
#       7     min_atoms=2,
#       8     num_trials=15,          # Trials per stoichiometry
#       9     optimize=True,
#      10     include_binaries=True,
#      11     include_ternaries=True,
#      12     max_stoichiometries=100,
#      13     crystal_systems=["hexagonal", "tetragonal"],
#      14     load_previous_runs=True,      # Load from all previous runs
#      15     skip_existing_formulas=False,  # Skip formulas we already have
#      16 )
#
# File ~/ouro/ggen/ggen/explorer.py:890, in ChemistryExplorer.explore(self, chemical_system, max_atoms, min_atoms, num_trials, optimize, include_binaries, include_ternaries, require_all_elements, max_stoichiometries, run_name, symmetry_bias, crystal_systems, load_previous_runs, skip_existing_formulas)
#     888 # Copy the structure to the new run's structures directory
#     889 if prev_candidate.structure is not None:
# --> 890     cif_path = self._save_structure_cif(
#     891         prev_candidate, structures_dir
#     892     )
#     893     prev_candidate.cif_path = cif_path
#     895 prev_candidate.generation_metadata["reused_from_previous"] = True
#
# File ~/ouro/ggen/ggen/explorer.py:473, in ChemistryExplorer._save_structure_cif(self, candidate, structures_dir)
#     468 filename = (
#     469     f"{candidate.formula}_{candidate.space_group_symbol.replace('/', '-')}.cif"
#     470 )
#     471 cif_path = structures_dir / filename
# --> 473 cif_writer = CifWriter(candidate.structure, symprec=0.1)
#     474 with open(cif_path, "w") as f:
#     475     f.write(str(cif_writer))
#
# File ~/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/io/cif.py:1574, in CifWriter.__init__(self, struct, symprec, write_magmoms, significant_figures, angle_tolerance, refine_struct, write_site_properties)
#    1572 spacegroup: tuple[str, int] = ("P 1", 1)
#    1573 if symprec is not None:
# -> 1574     spg_analyzer = SpacegroupAnalyzer(struct, symprec, angle_tolerance=angle_tolerance)
#    1575     spacegroup = (
#    1576         spg_analyzer.get_space_group_symbol(),
#    1577         spg_analyzer.get_space_group_number(),
#    1578     )
#    1580     if refine_struct:
#    1581         # Need the refined structure when using symprec. This converts
#    1582         # primitive to conventional structures, the standard for CIF.
#
# File ~/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/symmetry/analyzer.py:152, in SpacegroupAnalyzer.__init__(self, structure, symprec, angle_tolerance)
#     145 else:  # if no magmoms given do not add to cell
#     146     self._cell = (
#     147         tuple(map(tuple, structure.lattice.matrix.tolist())),
#     148         tuple(map(tuple, structure.frac_coords.tolist())),
#     149         tuple(zs),
#     150     )
# --> 152 self._space_group_data = _get_symmetry_dataset(self._cell, symprec, angle_tolerance)
#
# File ~/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/pymatgen/symmetry/analyzer.py:80, in _get_symmetry_dataset(cell, symprec, angle_tolerance)
#      78 dataset = spglib.get_symmetry_dataset(cell, symprec=symprec, angle_tolerance=angle_tolerance)
#      79 if dataset is None:
# ---> 80     raise SymmetryUndeterminedError(spglib.get_error_message())
#      81 return dataset
#
# SymmetryUndeterminedError: too close distance between atoms

# %% [markdown]
# ## Explore the Results

# %%
print(f"Chemical System: {result.chemical_system}")
print(f"Elements: {result.elements}") 
print(f"Total candidates attempted: {result.num_candidates}")
print(f"Successful generations: {result.num_successful}")
print(f"Failed generations: {result.num_failed}")
print(f"Phases on convex hull: {len(result.hull_entries)}")
print(f"Total time: {result.total_time_seconds:.1f}s")
print(f"\nResults saved to: {result.run_directory}")
print(f"Database: {result.database_path}")
# Out:
# Chemical System: Co-Fe-Mn
# Elements: ['Co', 'Fe', 'Mn']
# Total candidates attempted: 158
# Successful generations: 158
# Failed generations: 0
# Phases on convex hull: 6
# Total time: 2703.3s
#
# Results saved to: exploration_runs/exploration_Co-Fe-Mn_20260102_160815
# Database: exploration_runs/exploration_Co-Fe-Mn_20260102_160815/exploration.db

# %% [markdown]
# ## View Stable Candidates
#
# Get the phases that are on or near the convex hull:

# %%
# Get candidates within 150 meV/atom of the hull
stable = explorer.get_stable_candidates(result, e_above_hull_cutoff=0.15)

print(f"Found {len(stable)} stable/near-stable phases:\n")
for c in stable:
    e_above = c.generation_metadata.get('e_above_hull', 0)
    # Extract timestamp from run name (e.g., "exploration_Co-Fe-Mn_20260102_121508" -> "121508")
    source_run = c.generation_metadata.get('source_run', '')
    run_time = source_run if source_run else 'current'
    print(f"  {c.formula:10s}  E={c.energy_per_atom:.4f} eV/atom  "
          f"SG={c.space_group_symbol:10s}  E_hull={e_above*1000:.1f} meV  run={run_time}")
# Out:
# Found 114 stable/near-stable phases:
#
#   CoFe11      E=-8.3460 eV/atom  SG=P2/m        E_hull=0.0 meV  run=current
#   Co9Fe10     E=-7.8325 eV/atom  SG=Cm          E_hull=0.0 meV  run=current
#   Co8Fe5Mn7   E=-8.1582 eV/atom  SG=P4/m        E_hull=0.0 meV  run=current
#   Co2FeMn9    E=-8.7369 eV/atom  SG=Cm          E_hull=0.0 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   FeMn19      E=-9.0517 eV/atom  SG=P1          E_hull=0.0 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co9Mn8      E=-7.9985 eV/atom  SG=P1          E_hull=0.0 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co4FeMn7    E=-8.3927 eV/atom  SG=Cm          E_hull=2.6 meV  run=current
#   Co18Mn      E=-7.1789 eV/atom  SG=P-1         E_hull=3.1 meV  run=current
#   CoFe12Mn7   E=-8.6042 eV/atom  SG=P1          E_hull=4.6 meV  run=current
#   Fe2Mn5      E=-8.8929 eV/atom  SG=C2/m        E_hull=5.9 meV  run=current
#   Co8Fe11Mn   E=-7.9565 eV/atom  SG=P1          E_hull=6.3 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co13Mn7     E=-7.7554 eV/atom  SG=P1          E_hull=7.5 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   FeMn12      E=-9.0257 eV/atom  SG=C2/m        E_hull=8.5 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   CoFe11Mn    E=-8.3942 eV/atom  SG=Cm          E_hull=8.6 meV  run=current
#   Co15Fe2     E=-7.2384 eV/atom  SG=C2/m        E_hull=9.2 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Fe11Mn2     E=-8.5249 eV/atom  SG=C2/m        E_hull=10.6 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co11Mn2     E=-7.3663 eV/atom  SG=P-1         E_hull=13.4 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Fe11Mn5     E=-8.6209 eV/atom  SG=P4/mmm      E_hull=17.4 meV  run=current
#   Co2Mn13     E=-8.7495 eV/atom  SG=P1          E_hull=17.7 meV  run=current
#   Co5Fe13Mn2  E=-8.1742 eV/atom  SG=P1          E_hull=19.3 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co5Mn2      E=-7.6176 eV/atom  SG=C2/m        E_hull=19.7 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co9Fe8      E=-7.7327 eV/atom  SG=R-3m        E_hull=20.1 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co13Fe5     E=-7.4563 eV/atom  SG=P-31m       E_hull=20.4 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   CoFe7Mn     E=-8.3622 eV/atom  SG=Cm          E_hull=21.5 meV  run=current
#   Co10Fe5Mn   E=-7.6321 eV/atom  SG=C2          E_hull=23.2 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co13FeMn2   E=-7.3980 eV/atom  SG=Pm          E_hull=27.8 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Fe13Mn5     E=-8.5876 eV/atom  SG=P-31m       E_hull=28.2 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co6Fe3Mn    E=-7.6863 eV/atom  SG=R3m         E_hull=28.3 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   CoFe13Mn4   E=-8.4915 eV/atom  SG=Amm2        E_hull=28.5 meV  run=current
#   CoFe5Mn9    E=-8.7213 eV/atom  SG=P1          E_hull=30.3 meV  run=current
#   Co16Fe3Mn   E=-7.3653 eV/atom  SG=Pm          E_hull=31.6 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co14Fe5     E=-7.4241 eV/atom  SG=P1          E_hull=31.7 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co13Fe2Mn   E=-7.3504 eV/atom  SG=Amm2        E_hull=36.5 meV  run=current
#   Co7Fe6Mn5   E=-8.0900 eV/atom  SG=Pm          E_hull=37.4 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co11FeMn4   E=-7.6433 eV/atom  SG=P1          E_hull=38.7 meV  run=current
#   Co3FeMn9    E=-8.5649 eV/atom  SG=Pm          E_hull=44.5 meV  run=current
#   Co9Fe3Mn    E=-7.5228 eV/atom  SG=R3m         E_hull=45.2 meV  run=current
#   Co5Fe8Mn2   E=-8.0583 eV/atom  SG=Cm          E_hull=47.8 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co12Fe3Mn2  E=-7.5261 eV/atom  SG=P1          E_hull=48.0 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co3Fe11Mn4  E=-8.3366 eV/atom  SG=P1          E_hull=48.1 meV  run=current
#   Co3Fe8Mn5   E=-8.3682 eV/atom  SG=Pm          E_hull=49.4 meV  run=current
#   Co11Fe3Mn5  E=-7.7962 eV/atom  SG=P1          E_hull=50.8 meV  run=current
#   Co8Fe3Mn    E=-7.5579 eV/atom  SG=Pm          E_hull=50.9 meV  run=current
#   Co19Fe      E=-7.0992 eV/atom  SG=Cm          E_hull=51.5 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co9Fe2Mn4   E=-7.7671 eV/atom  SG=P1          E_hull=51.5 meV  run=current
#   FeMn8       E=-8.9581 eV/atom  SG=P1          E_hull=53.9 meV  run=current
#   Co3Fe6Mn10  E=-8.5450 eV/atom  SG=P1          E_hull=54.2 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co5Fe3Mn6   E=-8.2133 eV/atom  SG=P4mm        E_hull=54.2 meV  run=current
#   Co6Fe4Mn9   E=-8.2995 eV/atom  SG=P1          E_hull=54.4 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co7Fe3Mn4   E=-7.9169 eV/atom  SG=P1          E_hull=57.7 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   CoFe7Mn12   E=-8.7122 eV/atom  SG=P1          E_hull=58.0 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co5Fe6Mn6   E=-8.2456 eV/atom  SG=Cm          E_hull=58.6 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co4Fe6Mn3   E=-8.1453 eV/atom  SG=Cm          E_hull=59.6 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co3Fe8Mn9   E=-8.4989 eV/atom  SG=P1          E_hull=59.7 meV  run=current
#   Co4Fe3      E=-7.6322 eV/atom  SG=I4mm        E_hull=60.4 meV  run=current
#   Fe7Mn       E=-8.4558 eV/atom  SG=Cmmm        E_hull=61.0 meV  run=current
#   Co4Fe7Mn8   E=-8.3982 eV/atom  SG=P1          E_hull=61.5 meV  run=current
#   Co15Fe3Mn2  E=-7.4381 eV/atom  SG=P1          E_hull=61.9 meV  run=current
#   Co4Fe11Mn   E=-8.1056 eV/atom  SG=P1          E_hull=62.8 meV  run=current
#   Co11Fe2Mn   E=-7.3653 eV/atom  SG=P1          E_hull=65.6 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co2Fe5Mn3   E=-8.3270 eV/atom  SG=Cm          E_hull=65.8 meV  run=current
#   Co19Mn      E=-7.1083 eV/atom  SG=P1          E_hull=68.6 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co13Fe5Mn2  E=-7.5727 eV/atom  SG=Pm          E_hull=70.4 meV  run=current
#   Co3Mn10     E=-8.5029 eV/atom  SG=Pm          E_hull=75.2 meV  run=current
#   Co17Fe3     E=-7.2184 eV/atom  SG=P1          E_hull=75.5 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co4Fe11Mn5  E=-8.2816 eV/atom  SG=Cm          E_hull=77.8 meV  run=current
#   Co5Fe       E=-7.2398 eV/atom  SG=P6/mmm      E_hull=78.0 meV  run=current
#   Fe6Mn5      E=-8.6506 eV/atom  SG=P1          E_hull=79.8 meV  run=current
#   Co18Fe      E=-7.0734 eV/atom  SG=Cm          E_hull=81.2 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co7FeMn6    E=-7.9779 eV/atom  SG=Pm          E_hull=83.0 meV  run=current
#   Co3Fe5Mn10  E=-8.5218 eV/atom  SG=Pm          E_hull=85.4 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   CoFeMn17    E=-8.8625 eV/atom  SG=Pm          E_hull=87.1 meV  run=current
#   Co5Fe4Mn9   E=-8.3353 eV/atom  SG=P1          E_hull=88.0 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co4Fe5Mn10  E=-8.4419 eV/atom  SG=P1          E_hull=88.1 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co7Fe7Mn4   E=-7.9993 eV/atom  SG=P1          E_hull=92.6 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Fe13Mn7     E=-8.5662 eV/atom  SG=P1          E_hull=96.4 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   CoFeMn11    E=-8.8012 eV/atom  SG=Cm          E_hull=97.8 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   CoFe19      E=-8.2814 eV/atom  SG=Cm          E_hull=100.6 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co5Fe5Mn7   E=-8.2428 eV/atom  SG=Pm          E_hull=100.7 meV  run=current
#   Co14Mn5     E=-7.4922 eV/atom  SG=P1          E_hull=101.1 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co15Mn2     E=-7.2074 eV/atom  SG=P1          E_hull=101.7 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co11Fe8     E=-7.5788 eV/atom  SG=Pm          E_hull=103.1 meV  run=current
#   Fe5Mn14     E=-8.8091 eV/atom  SG=P1          E_hull=104.3 meV  run=current
#   Co4Fe3Mn11  E=-8.4667 eV/atom  SG=P1          E_hull=104.4 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co8Fe3Mn6   E=-7.9534 eV/atom  SG=P1          E_hull=104.5 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co6FeMn13   E=-8.3593 eV/atom  SG=P1          E_hull=105.7 meV  run=current
#   Co9Fe5Mn3   E=-7.7564 eV/atom  SG=P1          E_hull=107.4 meV  run=current
#   Co10FeMn8   E=-7.9108 eV/atom  SG=Pm          E_hull=107.5 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co11Fe2Mn6  E=-7.7675 eV/atom  SG=Pm          E_hull=111.2 meV  run=current
#   Co11Fe6Mn3  E=-7.7059 eV/atom  SG=P1          E_hull=111.8 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co8Fe8Mn    E=-7.7599 eV/atom  SG=P1          E_hull=114.0 meV  run=current
#   Co3Fe5Mn11  E=-8.5198 eV/atom  SG=P1          E_hull=114.6 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co2Fe6Mn11  E=-8.5780 eV/atom  SG=P1          E_hull=117.0 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co5Fe12Mn3  E=-8.1085 eV/atom  SG=P1          E_hull=118.4 meV  run=current
#   Co4Fe5Mn9   E=-8.3783 eV/atom  SG=P1          E_hull=118.7 meV  run=current
#   Co10Fe4Mn3  E=-7.6572 eV/atom  SG=P1          E_hull=122.4 meV  run=current
#   CoFe8Mn4    E=-8.4283 eV/atom  SG=P1          E_hull=123.3 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co14Fe4Mn   E=-7.3648 eV/atom  SG=P1          E_hull=124.1 meV  run=current
#   CoFe2Mn8    E=-8.6825 eV/atom  SG=P-1         E_hull=124.1 meV  run=current
#   Co2Fe5Mn5   E=-8.3863 eV/atom  SG=P31m        E_hull=128.1 meV  run=current
#   Co2FeMn16   E=-8.7183 eV/atom  SG=P1          E_hull=128.4 meV  run=current
#   CoFe6Mn10   E=-8.6240 eV/atom  SG=P31m        E_hull=128.8 meV  run=current
#   Co5Fe9Mn3   E=-8.0568 eV/atom  SG=P1          E_hull=129.7 meV  run=current
#   Co4Fe7Mn4   E=-8.1506 eV/atom  SG=P1          E_hull=132.2 meV  run=current
#   Co7Fe5Mn8   E=-8.1265 eV/atom  SG=Cm          E_hull=132.9 meV  run=current
#   Fe13Mn3     E=-8.4214 eV/atom  SG=P2/m        E_hull=135.8 meV  run=current
#   Co10Fe4Mn5  E=-7.7840 eV/atom  SG=P1          E_hull=138.7 meV  run=current
#   Co12Fe4Mn3  E=-7.5662 eV/atom  SG=P1          E_hull=139.7 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co5Fe10Mn3  E=-8.0604 eV/atom  SG=Pm          E_hull=141.1 meV  run=current
#   Co4Fe3Mn13  E=-8.4838 eV/atom  SG=P1          E_hull=142.5 meV  run=current
#   Co4FeMn8    E=-8.3085 eV/atom  SG=Pm          E_hull=143.3 meV  run=exploration_Co-Fe-Mn_20260102_153726
#   Co2Fe7Mn9   E=-8.4926 eV/atom  SG=P1          E_hull=144.9 meV  run=current
#   Co10FeMn2   E=-7.3603 eV/atom  SG=P1          E_hull=145.5 meV  run=current
#   Co4Fe7Mn3   E=-8.0729 eV/atom  SG=P1          E_hull=149.9 meV  run=exploration_Co-Fe-Mn_20260102_153726

# %% [markdown]
# ## View the Phase Diagram

# %%
# Plot the phase diagram (for ternary systems)
if result.phase_diagram is not None:
    try:
        fig = explorer.plot_phase_diagram(result, show_unstable=0.150)
        fig.show()
    except Exception as e:
        print(f"Phase diagram plotting not available: {e}")
else:
    print("No phase diagram available (need at least 2 valid candidates)")

# %% [markdown]
# ## Export Summary

# %%
# Export a JSON summary of the exploration
summary = explorer.export_summary(
    result,
    output_path=result.run_directory / "summary.json"
)

print("Summary exported!")
print(f"Hull entries: {summary['hull_entries']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Export a JSON summary of the exploration
#       2 summary = explorer.export_summary(
# ----> 3     result,
#       4     output_path=result.run_directory / "summary.json"
#       5 )
#       7 print("Summary exported!")
#       8 print(f"Hull entries: {summary['hull_entries']}")
#
# NameError: name 'result' is not defined

# %% [markdown]
# ## Inspect Individual Structures

# %%
# Get the most stable structure
if result.hull_entries:
    best = result.hull_entries[0]
    print(f"Most stable: {best.formula}")
    print(f"Energy: {best.energy_per_atom:.4f} eV/atom")
    print(f"Space group: {best.space_group_symbol} (#{best.space_group_number})")
    print(f"CIF file: {best.cif_path}")
    
    # View with pymatviz if available
from pymatviz import StructureWidget
StructureWidget(best.structure)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Get the most stable structure
# ----> 2 if result.hull_entries:
#       3     best = result.hull_entries[0]
#       4     print(f"Most stable: {best.formula}")
#
# NameError: name 'result' is not defined

# %% [markdown]
# ## Load a Previous Run
#
# You can reload a previous exploration from its directory:

# %%
# Load a previous run
# loaded = ChemistryExplorer.load_run("./exploration_runs/your_run_name")
# print(f"Loaded {loaded.num_candidates} candidates")

# %% [markdown]
# ## Query the SQLite Database Directly
#
# The SQLite database allows flexible querying:

# %%
import sqlite3
import pandas as pd

# Connect to the database
conn = sqlite3.connect(str(result.database_path))

# Query all candidates
df = pd.read_sql_query("""
    SELECT formula, energy_per_atom, space_group_symbol, 
           e_above_hull, is_on_hull, is_valid
    FROM candidates
    WHERE is_valid = 1
    ORDER BY e_above_hull ASC
""", conn)

print("All valid candidates:")
df
# Out:
# All valid candidates:
#        formula  energy_per_atom space_group_symbol  e_above_hull  is_on_hull  \
# 0           Co        -7.079214              Fm-3m           NaN           0
# 1           Fe        -8.435699              Im-3m           NaN           0
# 2           Mn        -9.025988              Im-3m           NaN           0
# 3       CoFe11        -8.346041               P2/m      0.000000           1
# 4      Co9Fe10        -7.832494                 Cm      0.000000           1
# ..         ...              ...                ...           ...         ...
# 156      Co3Fe        -6.336643             P6/mmm      1.100379           0
# 157      FeMn3        -7.813682             P6/mmm      1.108315           0
# 158  Co5Fe3Mn2        -6.607213                 Cm      1.313445           0
# 159  Co2Fe7Mn7        -6.144474                 P1      2.437319           0
# 160  Co4Fe2Mn9        -8.455341                 Cm      4.274131           0
#
#      is_valid
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 156         1
# 157         1
# 158         1
# 159         1
# 160         1
#
# [161 rows x 6 columns]
