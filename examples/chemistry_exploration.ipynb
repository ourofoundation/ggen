# %% [markdown]
# # Chemistry Exploration with ggen
#
# This notebook demonstrates how to systematically explore a chemical space by:
# 1. Specifying a chemical system (e.g., "Li-Co-O")
# 2. Generating candidate structures across different stoichiometries
# 3. Storing all data in SQLite for persistence
# 4. Building a phase diagram to identify thermodynamically stable candidates

# %%
# %pip install -e ..
# Out:
# Obtaining file:///Users/mmoderwell/ouro/ggen
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.20.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (2.4.0)
# Requirement already satisfied: scipy>=1.7.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (1.16.0)
# Requirement already satisfied: pymatgen>=2023.0.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (2025.10.7)
# Requirement already satisfied: pyxtal>=0.5.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (1.0.9)
# Requirement already satisfied: ase>=3.22.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (3.24.0)
# Requirement already satisfied: requests>=2.25.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (2.32.3)
# Requirement already satisfied: orb-models>=0.1.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ggen==0.1.0) (0.5.4)
# Requirement already satisfied: matplotlib>=3.3.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ase>=3.22.0->ggen==0.1.0) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (2.9.0.post0)
# Requirement already satisfied: cached_path>=1.6.7 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from orb-models>=0.1.0->ggen==0.1.0) (1.7.3)
# Requirement already satisfied: torch<3.0.0,>=2.6.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from orb-models>=0.1.0->ggen==0.1.0) (2.7.1)
# Requirement already satisfied: dm-tree==0.1.8 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from orb-models>=0.1.0->ggen==0.1.0) (0.1.8)
# Requirement already satisfied: tqdm>=4.66.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from orb-models>=0.1.0->ggen==0.1.0) (4.67.1)
# Requirement already satisfied: filelock in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (4.14.1)
# Requirement already satisfied: setuptools in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (75.6.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (3.1.4)
# Requirement already satisfied: fsspec in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (2024.10.0)
# Requirement already satisfied: rich<14.0,>=12.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (13.9.4)
# Requirement already satisfied: boto3<2.0,>=1.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.39.3)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.19.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.8.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (0.33.2)
# Requirement already satisfied: botocore<1.40.0,>=1.39.3 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from boto3<2.0,>=1.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.39.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from boto3<2.0,>=1.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from boto3<2.0,>=1.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (0.13.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from botocore<1.40.0,>=1.39.3->boto3<2.0,>=1.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.3.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.40.3)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.25.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (5.29.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (4.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.8.1->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (6.0.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.8.1->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (1.1.5)
# Requirement already satisfied: six>=1.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase>=3.22.0->ggen==0.1.0) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from requests>=2.25.0->ggen==0.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from requests>=2.25.0->ggen==0.1.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from requests>=2.25.0->ggen==0.1.0) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from rich<14.0,>=12.1->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from rich<14.0,>=12.1->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (2.18.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (0.6.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.1->cached_path>=1.6.7->orb-models>=0.1.0->ggen==0.1.0) (0.1.2)
# Requirement already satisfied: bibtexparser>=1.4.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (1.4.3)
# Requirement already satisfied: joblib>=1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (1.4.2)
# Requirement already satisfied: monty>=2025.1.9 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (2025.1.9)
# Requirement already satisfied: orjson<4,>=3.10 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (3.10.18)
# Requirement already satisfied: palettable>=3.3.3 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (3.3.3)
# Requirement already satisfied: pandas>=2 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (2.3.1)
# Requirement already satisfied: plotly>=5.0.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (6.5.0)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (0.18.10)
# Requirement already satisfied: spglib>=2.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (2.5.0)
# Requirement already satisfied: tabulate>=0.9 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (0.9.0)
# Requirement already satisfied: uncertainties>=3.1.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pymatgen>=2023.0.0->ggen==0.1.0) (3.2.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pandas>=2->pymatgen>=2023.0.0->ggen==0.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pandas>=2->pymatgen>=2023.0.0->ggen==0.1.0) (2024.2)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from plotly>=5.0.0->pymatgen>=2023.0.0->ggen==0.1.0) (2.14.0)
# Requirement already satisfied: vasprun-xml>=1.0.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyxtal>=0.5.0->ggen==0.1.0) (1.0.4)
# Requirement already satisfied: importlib_metadata>=1.4 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyxtal>=0.5.0->ggen==0.1.0) (8.7.0)
# Requirement already satisfied: pyocse>=0.1.1 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyxtal>=0.5.0->ggen==0.1.0) (0.1.2)
# Requirement already satisfied: psutil in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyxtal>=0.5.0->ggen==0.1.0) (6.1.0)
# Requirement already satisfied: zipp>=3.20 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from importlib_metadata>=1.4->pyxtal>=0.5.0->ggen==0.1.0) (3.23.0)
# Requirement already satisfied: toml in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyocse>=0.1.1->pyxtal>=0.5.0->ggen==0.1.0) (0.10.2)
# Requirement already satisfied: xmltodict in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from pyocse>=0.1.1->pyxtal>=0.5.0->ggen==0.1.0) (0.14.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from ruamel.yaml>=0.17.0->pymatgen>=2023.0.0->ggen==0.1.0) (0.2.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (1.3.0)
# Requirement already satisfied: lxml>=4.2.5 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from vasprun-xml>=1.0.4->pyxtal>=0.5.0->ggen==0.1.0) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages (from jinja2->torch<3.0.0,>=2.6.0->orb-models>=0.1.0->ggen==0.1.0) (3.0.2)
# Building wheels for collected packages: ggen
#   Building editable for ggen (pyproject.toml) ... done
#   Created wheel for ggen: filename=ggen-0.1.0-0.editable-py3-none-any.whl size=7756 sha256=ca39e4e362bf559abe7cd95395ba89e60f1672b1023bda8ef884651bc428dbf3
#   Stored in directory: /private/var/folders/zw/zcpqh2ss43v0d8_8mdqcds440000gn/T/pip-ephem-wheel-cache-1eqxooi6/wheels/ac/6f/ca/e5e77e53988e12825fc0b1323c5ae56703f9c5eab46d137fdd
# Successfully built ggen
# Installing collected packages: ggen
#   Attempting uninstall: ggen
#     Found existing installation: ggen 0.1.0
#     Uninstalling ggen-0.1.0:
#       Successfully uninstalled ggen-0.1.0
# Successfully installed ggen-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
logging.basicConfig(level=logging.INFO)

# %%
from ggen import ChemistryExplorer

# %% [markdown]
# ## Initialize the Explorer
#
# Create a `ChemistryExplorer` instance. You can optionally specify:
# - `calculator`: Custom ASE calculator (defaults to ORB)
# - `random_seed`: For reproducibility
# - `output_dir`: Where to store results

# %%
explorer = ChemistryExplorer(
    # random_seed=144,
    output_dir="./exploration_runs"
)

# %% [markdown]
# ## Preview Stoichiometries
#
# Before running the full exploration, you can preview what stoichiometries will be generated:

# %%
# Parse the chemical system
elements = explorer.parse_chemical_system("Fe-Mn-Bi")
print(f"Elements: {elements}")

# Enumerate stoichiometries
stoichiometries = explorer.enumerate_stoichiometries(
    elements=elements,
    max_atoms=8,
    min_atoms=2,
    include_binaries=True,
    include_ternaries=True,
)

print(f"\nTotal stoichiometries: {len(stoichiometries)}")
print("\nFirst 10:")
for s in stoichiometries[:10]:
    formula = "".join(f"{el}{c if c > 1 else ''}" for el, c in sorted(s.items()))
    print(f"  {formula}: {s}")
# Out:
# Elements: ['Bi', 'Fe', 'Mn']
#
# Total stoichiometries: 115
#
# First 10:
#   BiFeMn: {'Bi': 1, 'Fe': 1, 'Mn': 1}
#   BiFeMn2: {'Bi': 1, 'Fe': 1, 'Mn': 2}
#   BiFe2Mn: {'Bi': 1, 'Fe': 2, 'Mn': 1}
#   Bi2FeMn: {'Bi': 2, 'Fe': 1, 'Mn': 1}
#   BiFeMn3: {'Bi': 1, 'Fe': 1, 'Mn': 3}
#   BiFe2Mn2: {'Bi': 1, 'Fe': 2, 'Mn': 2}
#   BiFe3Mn: {'Bi': 1, 'Fe': 3, 'Mn': 1}
#   Bi2FeMn2: {'Bi': 2, 'Fe': 1, 'Mn': 2}
#   Bi2Fe2Mn: {'Bi': 2, 'Fe': 2, 'Mn': 1}
#   Bi3FeMn: {'Bi': 3, 'Fe': 1, 'Mn': 1}

# %% [markdown]
# ## Run the Exploration
#
# Now let's run the full exploration. This will:
# 1. Generate structures for each stoichiometry
# 2. Optimize them using the ORB calculator
# 3. Store results in SQLite + CIF files
# 4. Build a phase diagram

# %%
result = explorer.explore(
    chemical_system="Fe-Sn-B",
    # Fe-Sn-Co
    # Fe-Mn-Ni
    # Fe-Mn-
    max_atoms=20,          
    min_atoms=2,
    num_trials=15,          # Trials per stoichiometry
    optimize=True,
    include_binaries=True,
    include_ternaries=True,
    max_stoichiometries=100,
    crystal_systems=["hexagonal", "tetragonal"],
    load_previous_runs=True,      # Load from all previous runs
    skip_existing_formulas=False,  # Skip formulas we already have
    preserve_symmetry=True,
)
# Out:
# INFO:ggen.explorer:Starting exploration of B-Fe-Sn
# INFO:ggen.explorer:Found 2 previous runs for B-Fe-Sn
# INFO:ggen.explorer:Loaded 0 candidates from exploration_B-Fe-Sn_20260105_150839
# INFO:ggen.explorer:Loaded 7 candidates from exploration_B-Fe-Sn_20260105_144834
# INFO:ggen.explorer:Loaded 7 unique structures from previous runs
# INFO:ggen.explorer:Exploring 100 stoichiometries
# INFO:ggen.explorer:[1/100] Generating B4Fe4Sn7
# INFO:ggen.explorer:Generating structure for B4Fe4Sn7
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B4Fe4Sn7 (elements=['B', 'Fe', 'Sn'], counts=[4, 4, 7])
# INFO:ggen.ggen:Found 32 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [111, 168, 177, 174, 83]
# INFO:ggen.ggen:Generating 3 trials in space group 111 (tetragonal)
# INFO:ggen.ggen:SG 111 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 177 (hexagonal)
# INFO:ggen.ggen:SG 177 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 174 (hexagonal)
# INFO:ggen.ggen:SG 174 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 83 (tetragonal)
# INFO:ggen.ggen:SG 83 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 174, energy=-68.7430 eV, score=-70.4130
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 57 steps, E=-80.7592 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=174 (P-6)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 2 steps, E=-80.7592 eV, symmetry preserved SG=174
# INFO:ggen.ggen:Optimization complete: 59 steps, final energy=-80.7592 eV
# INFO:ggen.ggen:Crystal generation complete: B4Fe4Sn7, SG=P-6 (#174), energy=-80.7592 eV
# INFO:ggen.explorer:[2/100] Generating B4Fe12Sn
# INFO:ggen.explorer:Generating structure for B4Fe12Sn
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B4Fe12Sn (elements=['B', 'Fe', 'Sn'], counts=[4, 12, 1])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [111, 187, 189, 83, 177]
# INFO:ggen.ggen:Generating 3 trials in space group 111 (tetragonal)
# INFO:ggen.ggen:SG 111 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 187 (hexagonal)
# INFO:ggen.ggen:SG 187 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 83 (tetragonal)
# INFO:ggen.ggen:SG 83 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 177 (hexagonal)
# INFO:ggen.ggen:SG 177 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 177, energy=-87.6683 eV, score=-89.3883
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 13 passed filter → 13 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 31 steps, E=-109.9509 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=191 (P6/mmm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2: Symmetry reduced 191 -> 1 (true instability), 400 steps, E=-132.7552 eV
# INFO:ggen.ggen:Optimization complete: 431 steps, final energy=-132.7552 eV
# INFO:ggen.ggen:Crystal generation complete: B4Fe12Sn, SG=P1 (#1), energy=-132.7552 eV
# INFO:ggen.explorer:[3/100] Generating B13Fe2Sn
# INFO:ggen.explorer:Generating structure for B13Fe2Sn
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B13Fe2Sn (elements=['B', 'Fe', 'Sn'], counts=[13, 2, 1])
# INFO:ggen.ggen:Found 32 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [89, 183, 168, 174, 99]
# INFO:ggen.ggen:Generating 3 trials in space group 89 (tetragonal)
# INFO:ggen.ggen:SG 89 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 183 (hexagonal)
# INFO:ggen.ggen:SG 183 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 174 (hexagonal)
# INFO:ggen.ggen:SG 174 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 99 (tetragonal)
# INFO:ggen.ggen:SG 99 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 183, energy=-68.6993 eV, score=-70.4793
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 12 passed filter → 12 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 400 steps, E=-92.9662 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=183 (P6mm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2: Symmetry reduced 183 -> 1 (true instability), 400 steps, E=-93.0886 eV
# INFO:ggen.ggen:Optimization complete: 800 steps, final energy=-93.0886 eV
# INFO:ggen.ggen:Crystal generation complete: B13Fe2Sn, SG=P1 (#1), energy=-93.0886 eV
# INFO:ggen.explorer:[4/100] Generating Fe9Sn11
# INFO:ggen.explorer:Generating structure for Fe9Sn11
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Fe9Sn11 (elements=['Fe', 'Sn'], counts=[9, 11])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [99, 189, 89, 187, 175]
# INFO:ggen.ggen:Generating 3 trials in space group 99 (tetragonal)
# INFO:ggen.ggen:SG 99 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 89 (tetragonal)
# INFO:ggen.ggen:SG 89 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 187 (hexagonal)
# INFO:ggen.ggen:SG 187 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 175, energy=-84.5166 eV, score=-86.1966
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 41 steps, E=-99.0635 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=191 (P6/mmm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 1 steps, E=-99.0635 eV, symmetry preserved SG=191
# INFO:ggen.ggen:Optimization complete: 42 steps, final energy=-99.0635 eV
# INFO:ggen.ggen:Crystal generation complete: Fe9Sn11, SG=P6/mmm (#191), energy=-99.0635 eV
# INFO:ggen.explorer:[5/100] Generating B2FeSn3
# INFO:ggen.explorer:Generating structure for B2FeSn3
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B2FeSn3 (elements=['B', 'Fe', 'Sn'], counts=[2, 1, 3])
# INFO:ggen.ggen:Found 32 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [89, 191, 168, 189, 111]
# INFO:ggen.ggen:Generating 3 trials in space group 89 (tetragonal)
# INFO:ggen.ggen:SG 89 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 191 (hexagonal)
# INFO:ggen.ggen:SG 191 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 111 (tetragonal)
# INFO:ggen.ggen:SG 111 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 189, energy=-27.9408 eV, score=-29.8008
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 16 steps, E=-28.4032 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=189 (P-62m)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2: Symmetry reduced 189 -> 8 (true instability), 166 steps, E=-31.2091 eV
# INFO:ggen.ggen:Optimization complete: 182 steps, final energy=-31.2091 eV
# INFO:ggen.ggen:Crystal generation complete: B2FeSn3, SG=Cm (#8), energy=-31.2091 eV
# INFO:ggen.explorer:[6/100] Generating B11Sn7
# INFO:ggen.explorer:Generating structure for B11Sn7
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B11Sn7 (elements=['B', 'Sn'], counts=[11, 7])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [115, 183, 75, 83, 89]
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 1 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 183 (hexagonal)
# INFO:ggen.ggen:SG 183 complete: 3/3 valid, 1 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 83 (tetragonal)
# INFO:ggen.ggen:SG 83 complete: 3/3 valid, 1 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 89 (tetragonal)
# INFO:ggen.ggen:SG 89 complete: 3/3 valid, 1 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 75, energy=-54.8160 eV, score=-55.4760
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 7 passed filter → 7 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 400 steps, E=-87.7337 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=75 (P4)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2: Symmetry reduced 75 -> 1 (true instability), 367 steps, E=-91.7701 eV
# INFO:ggen.ggen:Optimization complete: 767 steps, final energy=-91.7701 eV
# INFO:ggen.ggen:Crystal generation complete: B11Sn7, SG=P1 (#1), energy=-91.7701 eV
# INFO:ggen.explorer:[7/100] Generating B4Fe2Sn13
# INFO:ggen.explorer:Generating structure for B4Fe2Sn13
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B4Fe2Sn13 (elements=['B', 'Fe', 'Sn'], counts=[4, 2, 13])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [123, 191, 115, 81, 187]
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 191 (hexagonal)
# INFO:ggen.ggen:SG 191 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 81 (tetragonal)
# INFO:ggen.ggen:SG 81 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 187 (hexagonal)
# INFO:ggen.ggen:SG 187 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 81, energy=-48.2833 eV, score=-49.0133
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 13 passed filter → 13 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 111 steps, E=-87.1399 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=81 (P-4)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 1 steps, E=-87.1399 eV, symmetry preserved SG=81
# INFO:ggen.ggen:Optimization complete: 112 steps, final energy=-87.1399 eV
# INFO:ggen.ggen:Crystal generation complete: B4Fe2Sn13, SG=P-4 (#81), energy=-87.1399 eV
# INFO:ggen.explorer:[8/100] Generating B2Fe10Sn7
# INFO:ggen.explorer:Generating structure for B2Fe10Sn7
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B2Fe10Sn7 (elements=['B', 'Fe', 'Sn'], counts=[2, 10, 7])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [99, 168, 83, 123, 177]
# INFO:ggen.ggen:Generating 3 trials in space group 99 (tetragonal)
# INFO:ggen.ggen:SG 99 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 83 (tetragonal)
# INFO:ggen.ggen:SG 83 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 177 (hexagonal)
# INFO:ggen.ggen:SG 177 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 177, energy=-80.8838 eV, score=-82.5938
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 51 steps, E=-108.0422 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=191 (P6/mmm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 3 steps, E=-108.0447 eV, symmetry preserved SG=191
# INFO:ggen.ggen:Optimization complete: 54 steps, final energy=-108.0447 eV
# INFO:ggen.ggen:Crystal generation complete: B2Fe10Sn7, SG=P6/mmm (#191), energy=-108.0447 eV
# INFO:ggen.explorer:[9/100] Generating B13Sn7
# INFO:ggen.explorer:Generating structure for B13Sn7
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B13Sn7 (elements=['B', 'Sn'], counts=[13, 7])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [115, 168, 183, 99, 174]
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 183 (hexagonal)
# INFO:ggen.ggen:SG 183 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 99 (tetragonal)
# INFO:ggen.ggen:SG 99 complete: 3/3 valid, 1 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 174 (hexagonal)
# INFO:ggen.ggen:SG 174 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 168, energy=-63.8049 eV, score=-65.4249
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 12 passed filter → 12 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 84 steps, E=-105.7124 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=168 (P6)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 2 steps, E=-105.7125 eV, symmetry preserved SG=168
# INFO:ggen.ggen:Optimization complete: 86 steps, final energy=-105.7125 eV
# INFO:ggen.ggen:Crystal generation complete: B13Sn7, SG=P6 (#168), energy=-105.7125 eV
# INFO:ggen.explorer:[10/100] Generating B2Fe2Sn5
# INFO:ggen.explorer:Generating structure for B2Fe2Sn5
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B2Fe2Sn5 (elements=['B', 'Fe', 'Sn'], counts=[2, 2, 5])
# INFO:ggen.ggen:Found 32 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [115, 177, 168, 187, 81]
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 177 (hexagonal)
# INFO:ggen.ggen:SG 177 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 187 (hexagonal)
# INFO:ggen.ggen:SG 187 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 81 (tetragonal)
# INFO:ggen.ggen:SG 81 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 81, energy=-38.8748 eV, score=-39.6248
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 24 steps, E=-41.5516 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=115 (P-4m2)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-41.5516 eV, symmetry preserved SG=115
# INFO:ggen.ggen:Optimization complete: 24 steps, final energy=-41.5516 eV
# INFO:ggen.ggen:Crystal generation complete: B2Fe2Sn5, SG=P-4m2 (#115), energy=-41.5516 eV
# INFO:ggen.explorer:[11/100] Generating B3Fe7Sn10
# INFO:ggen.explorer:Generating structure for B3Fe7Sn10
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B3Fe7Sn10 (elements=['B', 'Fe', 'Sn'], counts=[3, 7, 10])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [83, 187, 81, 75, 168]
# INFO:ggen.ggen:Generating 3 trials in space group 83 (tetragonal)
# INFO:ggen.ggen:SG 83 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 187 (hexagonal)
# INFO:ggen.ggen:SG 187 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 81 (tetragonal)
# INFO:ggen.ggen:SG 81 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 75, energy=-96.6929 eV, score=-97.3529
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 92 steps, E=-114.4212 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=75 (P4)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-114.4212 eV, symmetry preserved SG=75
# INFO:ggen.ggen:Optimization complete: 92 steps, final energy=-114.4212 eV
# INFO:ggen.ggen:Crystal generation complete: B3Fe7Sn10, SG=P4 (#75), energy=-114.4212 eV
# INFO:ggen.explorer:[12/100] Generating B10Fe9Sn
# INFO:ggen.explorer:Generating structure for B10Fe9Sn
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B10Fe9Sn (elements=['B', 'Fe', 'Sn'], counts=[10, 9, 1])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [115, 183, 168, 75, 99]
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 183 (hexagonal)
# INFO:ggen.ggen:SG 183 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 99 (tetragonal)
# INFO:ggen.ggen:SG 99 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 115, energy=-93.0189 eV, score=-94.1089
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 14 passed filter → 14 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 109 steps, E=-139.2255 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=115 (P-4m2)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 3 steps, E=-139.2256 eV, symmetry preserved SG=115
# INFO:ggen.ggen:Optimization complete: 112 steps, final energy=-139.2256 eV
# INFO:ggen.ggen:Crystal generation complete: B10Fe9Sn, SG=P-4m2 (#115), energy=-139.2256 eV
# INFO:ggen.explorer:[13/100] Generating B8Fe3Sn9
# INFO:ggen.explorer:Generating structure for B8Fe3Sn9
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B8Fe3Sn9 (elements=['B', 'Fe', 'Sn'], counts=[8, 3, 9])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [111, 187, 168, 99, 81]
# INFO:ggen.ggen:Generating 3 trials in space group 111 (tetragonal)
# INFO:ggen.ggen:SG 111 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 187 (hexagonal)
# INFO:ggen.ggen:SG 187 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 99 (tetragonal)
# INFO:ggen.ggen:SG 99 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 81 (tetragonal)
# INFO:ggen.ggen:SG 81 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 81, energy=-74.7638 eV, score=-75.4738
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 55 steps, E=-94.1672 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=81 (P-4)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 3 steps, E=-94.1673 eV, symmetry preserved SG=81
# INFO:ggen.ggen:Optimization complete: 58 steps, final energy=-94.1673 eV
# INFO:ggen.ggen:Crystal generation complete: B8Fe3Sn9, SG=P-4 (#81), energy=-94.1673 eV
# INFO:ggen.explorer:[14/100] Generating Fe2Sn7
# INFO:ggen.explorer:Generating structure for Fe2Sn7
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Fe2Sn7 (elements=['Fe', 'Sn'], counts=[2, 7])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [115, 189, 111, 123, 191]
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 111 (tetragonal)
# INFO:ggen.ggen:SG 111 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 191 (hexagonal)
# INFO:ggen.ggen:SG 191 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 111, energy=-24.1298 eV, score=-25.1998
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 48 steps, E=-38.3541 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=123 (P4/mmm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-38.3541 eV, symmetry preserved SG=123
# INFO:ggen.ggen:Optimization complete: 48 steps, final energy=-38.3541 eV
# INFO:ggen.ggen:Crystal generation complete: Fe2Sn7, SG=P4/mmm (#123), energy=-38.3541 eV
# INFO:ggen.explorer:[15/100] Generating BFeSn6
# INFO:ggen.explorer:Generating structure for BFeSn6
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for BFeSn6 (elements=['B', 'Fe', 'Sn'], counts=[1, 1, 6])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [99, 191, 111, 168, 75]
# INFO:ggen.ggen:Generating 3 trials in space group 99 (tetragonal)
# INFO:ggen.ggen:SG 99 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 191 (hexagonal)
# INFO:ggen.ggen:SG 191 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 111 (tetragonal)
# INFO:ggen.ggen:SG 111 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 168, energy=-27.5793 eV, score=-29.2093
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 377 steps, E=-35.2410 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=183 (P6mm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-35.2410 eV, symmetry preserved SG=183
# INFO:ggen.ggen:Optimization complete: 377 steps, final energy=-35.2410 eV
# INFO:ggen.ggen:Crystal generation complete: BFeSn6, SG=P6mm (#183), energy=-35.2410 eV
# INFO:ggen.explorer:[16/100] Generating B2Fe5Sn13
# INFO:ggen.explorer:Generating structure for B2Fe5Sn13
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B2Fe5Sn13 (elements=['B', 'Fe', 'Sn'], counts=[2, 5, 13])
# INFO:ggen.ggen:Found 32 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [75, 191, 168, 81, 187]
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 191 (hexagonal)
# INFO:ggen.ggen:SG 191 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 81 (tetragonal)
# INFO:ggen.ggen:SG 81 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 187 (hexagonal)
# INFO:ggen.ggen:SG 187 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 168, energy=-74.9866 eV, score=-76.6066
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 47 steps, E=-99.8874 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=168 (P6)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-99.8874 eV, symmetry preserved SG=168
# INFO:ggen.ggen:Optimization complete: 47 steps, final energy=-99.8874 eV
# INFO:ggen.ggen:Crystal generation complete: B2Fe5Sn13, SG=P6 (#168), energy=-99.8874 eV
# INFO:ggen.explorer:[17/100] Generating BFe7Sn2
# INFO:ggen.explorer:Generating structure for BFe7Sn2
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for BFe7Sn2 (elements=['B', 'Fe', 'Sn'], counts=[1, 7, 2])
# INFO:ggen.ggen:Found 32 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [81, 183, 168, 89, 175]
# INFO:ggen.ggen:Generating 3 trials in space group 81 (tetragonal)
# INFO:ggen.ggen:SG 81 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 183 (hexagonal)
# INFO:ggen.ggen:SG 183 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 89 (tetragonal)
# INFO:ggen.ggen:SG 89 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 175, energy=-63.2895 eV, score=-64.9995
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 24 steps, E=-69.5288 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=191 (P6/mmm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 1 steps, E=-69.5288 eV, symmetry preserved SG=191
# INFO:ggen.ggen:Optimization complete: 25 steps, final energy=-69.5288 eV
# INFO:ggen.ggen:Crystal generation complete: BFe7Sn2, SG=P6/mmm (#191), energy=-69.5288 eV
# INFO:ggen.explorer:[18/100] Generating B6Fe5Sn5
# INFO:ggen.explorer:Generating structure for B6Fe5Sn5
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B6Fe5Sn5 (elements=['B', 'Fe', 'Sn'], counts=[6, 5, 5])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [81, 189, 175, 177, 183]
# INFO:ggen.ggen:Generating 3 trials in space group 81 (tetragonal)
# INFO:ggen.ggen:SG 81 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 189 (hexagonal)
# INFO:ggen.ggen:SG 189 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 177 (hexagonal)
# INFO:ggen.ggen:SG 177 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 183 (hexagonal)
# INFO:ggen.ggen:SG 183 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 177, energy=-64.6365 eV, score=-66.3365
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 400 steps, E=-67.7840 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=191 (P6/mmm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2: Symmetry reduced 191 -> 1 (true instability), 400 steps, E=-66.3799 eV
# INFO:ggen.ggen:Optimization complete: 800 steps, final energy=-66.3799 eV
# INFO:ggen.ggen:Crystal generation complete: B6Fe5Sn5, SG=P1 (#1), energy=-66.3799 eV
# INFO:ggen.explorer:[19/100] Generating BSn19
# INFO:ggen.explorer:Generating structure for BSn19
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for BSn19 (elements=['B', 'Sn'], counts=[1, 19])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [99, 183, 123, 174, 89]
# INFO:ggen.ggen:Generating 3 trials in space group 99 (tetragonal)
# INFO:ggen.ggen:SG 99 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 183 (hexagonal)
# INFO:ggen.ggen:SG 183 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 123 (tetragonal)
# INFO:ggen.ggen:SG 123 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 174 (hexagonal)
# INFO:ggen.ggen:SG 174 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 89 (tetragonal)
# INFO:ggen.ggen:SG 89 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 183, energy=-10.0681 eV, score=-11.8281
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 400 steps, E=-75.1524 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=183 (P6mm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 400 steps, E=-75.4230 eV, symmetry preserved SG=183
# INFO:ggen.ggen:Optimization complete: 800 steps, final energy=-75.4230 eV
# INFO:ggen.ggen:Crystal generation complete: BSn19, SG=P6mm (#183), energy=-75.4230 eV
# INFO:ggen.explorer:[20/100] Generating B7Fe8Sn
# INFO:ggen.explorer:Generating structure for B7Fe8Sn
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B7Fe8Sn (elements=['B', 'Fe', 'Sn'], counts=[7, 8, 1])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [83, 177, 75, 174, 81]
# INFO:ggen.ggen:Generating 3 trials in space group 83 (tetragonal)
# INFO:ggen.ggen:SG 83 complete: 3/3 valid, 1 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 177 (hexagonal)
# INFO:ggen.ggen:SG 177 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 75 (tetragonal)
# INFO:ggen.ggen:SG 75 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 174 (hexagonal)
# INFO:ggen.ggen:SG 174 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 81 (tetragonal)
# INFO:ggen.ggen:SG 81 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 174, energy=-98.9219 eV, score=-100.5919
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 13 passed filter → 13 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 52 steps, E=-111.5612 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=174 (P-6)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2: Symmetry reduced 174 -> 8 (true instability), 207 steps, E=-117.6900 eV
# INFO:ggen.ggen:Optimization complete: 259 steps, final energy=-117.6900 eV
# INFO:ggen.ggen:Crystal generation complete: B7Fe8Sn, SG=Cm (#8), energy=-117.6900 eV
# INFO:ggen.explorer:[21/100] Generating B11Fe5Sn4
# INFO:ggen.explorer:Generating structure for B11Fe5Sn4
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B11Fe5Sn4 (elements=['B', 'Fe', 'Sn'], counts=[11, 5, 4])
# INFO:ggen.ggen:Found 34 compatible space groups
# INFO:ggen.ggen:Filtered to 16 space groups in systems: ['hexagonal', 'tetragonal']
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [115, 175, 191, 177, 83]
# INFO:ggen.ggen:Generating 3 trials in space group 115 (tetragonal)
# INFO:ggen.ggen:SG 115 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 175 (hexagonal)
# INFO:ggen.ggen:SG 175 complete: 3/3 valid, 1 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 191 (hexagonal)
# INFO:ggen.ggen:SG 191 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 177 (hexagonal)
# INFO:ggen.ggen:SG 177 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 83 (tetragonal)
# INFO:ggen.ggen:SG 83 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 191, energy=-88.9337 eV, score=-90.7737
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 11 passed filter → 11 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 29 steps, E=-111.0805 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=191 (P6/mmm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2: Symmetry reduced 191 -> 1 (true instability), 333 steps, E=-127.5892 eV
# INFO:ggen.ggen:Optimization complete: 362 steps, final energy=-127.5892 eV
# INFO:ggen.ggen:Crystal generation complete: B11Fe5Sn4, SG=P1 (#1), energy=-127.5892 eV
# INFO:ggen.explorer:[22/100] Generating B8Fe3Sn6
# ...
# INFO:ggen.ggen:SG 204 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 177, energy=-10.5034 eV, score=-12.2634
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 44 steps, E=-10.9043 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=191 (P6/mmm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-10.9043 eV, symmetry preserved SG=191
# INFO:ggen.ggen:Optimization complete: 44 steps, final energy=-10.9043 eV
# INFO:ggen.ggen:Crystal generation complete: B2, SG=P6/mmm (#191), energy=-10.9043 eV
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for B4 (elements=['B'], counts=[4])
# INFO:ggen.ggen:Found 185 compatible space groups
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [35, 82, 157, 173, 225]
# INFO:ggen.ggen:Generating 3 trials in space group 35 (orthorhombic)
# INFO:ggen.ggen:SG 35 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 82 (tetragonal)
# INFO:ggen.ggen:SG 82 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 157 (trigonal)
# INFO:ggen.ggen:SG 157 complete: 3/3 valid, 2 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 173 (hexagonal)
# INFO:ggen.ggen:SG 173 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 225 (cubic)
# INFO:ggen.ggen:SG 225 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 35, energy=-22.2240 eV, score=-22.5640
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 13 passed filter → 13 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 11 steps, E=-24.1382 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=65 (Cmmm)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-24.1382 eV, symmetry preserved SG=65
# INFO:ggen.ggen:Optimization complete: 11 steps, final energy=-24.1382 eV
# INFO:ggen.ggen:Crystal generation complete: B4, SG=Cmmm (#65), energy=-24.1382 eV
# INFO:ggen.explorer:Terminal B: E=-6.0345 eV/atom, SG=Cmmm
# INFO:ggen.explorer:Generating terminal element structure for Fe
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Fe (elements=['Fe'], counts=[1])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [25, 89, 150, 183, 221]
# INFO:ggen.ggen:Generating 3 trials in space group 25 (orthorhombic)
# INFO:ggen.ggen:SG 25 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 89 (tetragonal)
# INFO:ggen.ggen:SG 89 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 150 (trigonal)
# INFO:ggen.ggen:SG 150 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 183 (hexagonal)
# INFO:ggen.ggen:SG 183 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 221 (cubic)
# INFO:ggen.ggen:SG 221 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 221, energy=-7.4235 eV, score=-9.6235
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 4 steps, E=-7.6632 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=221 (Pm-3m)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-7.6632 eV, symmetry preserved SG=221
# INFO:ggen.ggen:Optimization complete: 4 steps, final energy=-7.6632 eV
# INFO:ggen.ggen:Crystal generation complete: Fe, SG=Pm-3m (#221), energy=-7.6632 eV
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Fe2 (elements=['Fe'], counts=[2])
# INFO:ggen.ggen:Found 133 compatible space groups
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [35, 97, 156, 188, 204]
# INFO:ggen.ggen:Generating 3 trials in space group 35 (orthorhombic)
# INFO:ggen.ggen:SG 35 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 97 (tetragonal)
# INFO:ggen.ggen:SG 97 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 156 (trigonal)
# INFO:ggen.ggen:SG 156 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 188 (hexagonal)
# INFO:ggen.ggen:SG 188 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 204 (cubic)
# INFO:ggen.ggen:SG 204 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 204, energy=-13.9062 eV, score=-15.9362
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 5 steps, E=-16.8714 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=229 (Im-3m)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-16.8714 eV, symmetry preserved SG=229
# INFO:ggen.ggen:Optimization complete: 5 steps, final energy=-16.8714 eV
# INFO:ggen.ggen:Crystal generation complete: Fe2, SG=Im-3m (#229), energy=-16.8714 eV
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Fe4 (elements=['Fe'], counts=[4])
# INFO:ggen.ggen:Found 185 compatible space groups
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [52, 102, 165, 174, 207]
# INFO:ggen.ggen:Generating 3 trials in space group 52 (orthorhombic)
# INFO:ggen.ggen:SG 52 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 102 (tetragonal)
# INFO:ggen.ggen:SG 102 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 165 (trigonal)
# INFO:ggen.ggen:SG 165 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 174 (hexagonal)
# INFO:ggen.ggen:SG 174 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 207 (cubic)
# INFO:ggen.ggen:SG 207 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 207, energy=-28.3210 eV, score=-30.3710
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 12 steps, E=-33.3658 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=225 (Fm-3m)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-33.3658 eV, symmetry preserved SG=225
# INFO:ggen.ggen:Optimization complete: 12 steps, final energy=-33.3658 eV
# INFO:ggen.ggen:Crystal generation complete: Fe4, SG=Fm-3m (#225), energy=-33.3658 eV
# INFO:ggen.explorer:Terminal Fe: E=-8.4357 eV/atom, SG=Im-3m
# INFO:ggen.explorer:Generating terminal element structure for Sn
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Sn (elements=['Sn'], counts=[1])
# INFO:ggen.ggen:Found 37 compatible space groups
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [25, 83, 164, 191, 221]
# INFO:ggen.ggen:Generating 3 trials in space group 25 (orthorhombic)
# INFO:ggen.ggen:SG 25 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 83 (tetragonal)
# INFO:ggen.ggen:SG 83 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 164 (trigonal)
# INFO:ggen.ggen:SG 164 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 191 (hexagonal)
# INFO:ggen.ggen:SG 191 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 221 (cubic)
# INFO:ggen.ggen:SG 221 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 221, energy=-3.8893 eV, score=-6.0893
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 4 steps, E=-3.9445 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=221 (Pm-3m)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-3.9445 eV, symmetry preserved SG=221
# INFO:ggen.ggen:Optimization complete: 4 steps, final energy=-3.9445 eV
# INFO:ggen.ggen:Crystal generation complete: Sn, SG=Pm-3m (#221), energy=-3.9445 eV
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Sn2 (elements=['Sn'], counts=[2])
# INFO:ggen.ggen:Found 133 compatible space groups
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [55, 100, 149, 168, 223]
# INFO:ggen.ggen:Generating 3 trials in space group 55 (orthorhombic)
# INFO:ggen.ggen:SG 55 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 100 (tetragonal)
# INFO:ggen.ggen:SG 100 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 149 (trigonal)
# INFO:ggen.ggen:SG 149 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 168 (hexagonal)
# INFO:ggen.ggen:SG 168 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 223 (cubic)
# INFO:ggen.ggen:SG 223 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 223, energy=-7.8526 eV, score=-10.0726
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 2 steps, E=-7.8608 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=229 (Im-3m)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-7.8608 eV, symmetry preserved SG=229
# INFO:ggen.ggen:Optimization complete: 2 steps, final energy=-7.8608 eV
# INFO:ggen.ggen:Crystal generation complete: Sn2, SG=Im-3m (#229), energy=-7.8608 eV
# /Users/mmoderwell/.pyenv/versions/3.12.0/envs/materials/lib/python3.12/site-packages/orb_models/utils.py:30: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# INFO:cached_path:cache of https://orbitalmaterials-public-models.s3.us-west-1.amazonaws.com/forcefields/orb-v3/orb-v3-conservative-inf-mpa-20250404.ckpt is up-to-date
# INFO:ggen.ggen:Starting crystal generation for Sn4 (elements=['Sn'], counts=[4])
# INFO:ggen.ggen:Found 185 compatible space groups
# INFO:ggen.ggen:Multi-spacegroup mode (symmetry_bias=0.00): trying 5 space groups: [58, 85, 147, 177, 221]
# INFO:ggen.ggen:Generating 3 trials in space group 58 (orthorhombic)
# INFO:ggen.ggen:SG 58 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 85 (tetragonal)
# INFO:ggen.ggen:SG 85 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 147 (trigonal)
# INFO:ggen.ggen:SG 147 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 177 (hexagonal)
# INFO:ggen.ggen:SG 177 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Generating 3 trials in space group 221 (cubic)
# INFO:ggen.ggen:SG 221 complete: 3/3 valid, 3 passed pre-filter
# INFO:ggen.ggen:Selected best candidate: SG 221, energy=-14.3202 eV, score=-16.5102
# INFO:ggen.ggen:Generation stats: 15 attempts → 15 valid → 15 passed filter → 15 evaluated
# INFO:ggen.ggen:Starting geometry optimization (symmetry-preserving)...
# INFO:ggen.ggen:Symmetry constraint applied (symprec=0.0100) - forces will be projected onto symmetry-allowed subspace
# INFO:ggen.ggen:Stage 1 complete: 5 steps, E=-15.7867 eV
# INFO:ggen.ggen:Stage 1 symmetry: SG=225 (Fm-3m)
# INFO:ggen.ggen:Stage 2: Unconstrained fine-tuning...
# INFO:ggen.ggen:Stage 2 complete: 0 steps, E=-15.7867 eV, symmetry preserved SG=225
# INFO:ggen.ggen:Optimization complete: 5 steps, final energy=-15.7867 eV
# INFO:ggen.ggen:Crystal generation complete: Sn4, SG=Fm-3m (#225), energy=-15.7867 eV
# INFO:ggen.explorer:Terminal Sn: E=-3.9467 eV/atom, SG=Fm-3m
# INFO:ggen.explorer:Using newly generated terminal B (new=-6.0345 vs prev=-6.0219 eV/atom)
# INFO:ggen.explorer:Using newly generated terminal Fe (new=-8.4357 vs prev=-8.4357 eV/atom)
# INFO:ggen.explorer:Using newly generated terminal Sn (new=-3.9467 vs prev=-3.9467 eV/atom)
# INFO:ggen.explorer:Building phase diagram with 104 compounds + 3 terminal elements
# INFO:ggen.explorer:Found 3 phases on the convex hull
# INFO:ggen.explorer:Exploration complete: 104 successful (4 from previous runs), 3 on hull, 3604.9s

# %% [markdown]
# ## Explore the Results

# %%
print(f"Chemical System: {result.chemical_system}")
print(f"Elements: {result.elements}") 
print(f"Total candidates attempted: {result.num_candidates}")
print(f"Successful generations: {result.num_successful}")
print(f"Failed generations: {result.num_failed}")
print(f"Phases on convex hull: {len(result.hull_entries)}")
print(f"Total time: {result.total_time_seconds:.1f}s")
print(f"\nResults saved to: {result.run_directory}")
print(f"Database: {result.database_path}")
# Out:
# Chemical System: B-Fe-Sn
# Elements: ['B', 'Fe', 'Sn']
# Total candidates attempted: 104
# Successful generations: 104
# Failed generations: 0
# Phases on convex hull: 3
# Total time: 3604.9s
#
# Results saved to: exploration_runs/exploration_B-Fe-Sn_20260105_150839
# Database: exploration_runs/exploration_B-Fe-Sn_20260105_150839/exploration.db

# %% [markdown]
# ## View Stable Candidates
#
# Get the phases that are on or near the convex hull:

# %%
# Get candidates within 150 meV/atom of the hull
stable = explorer.get_stable_candidates(result, e_above_hull_cutoff=0.15)

print(f"Found {len(stable)} stable/near-stable phases:\n")
for c in stable:
    e_above = c.generation_metadata.get('e_above_hull', 0)
    # Extract timestamp from run name (e.g., "exploration_Co-Fe-Mn_20260102_121508" -> "121508")
    source_run = c.generation_metadata.get('source_run', '')
    run_time = source_run if source_run else 'current'
    print(f"  {c.formula:10s}  E={c.energy_per_atom:.4f} eV/atom  "
          f"SG={c.space_group_symbol:10s}  E_hull={e_above*1000:.1f} meV  run={run_time}")
# Out:
# Found 10 stable/near-stable phases:
#
#   B9Fe3Sn     E=-6.7929 eV/atom  SG=C2          E_hull=0.0 meV  run=current
#   B8Fe9       E=-7.7849 eV/atom  SG=C2/m        E_hull=0.0 meV  run=current
#   B15Sn       E=-6.1392 eV/atom  SG=P1          E_hull=0.0 meV  run=current
#   B4Fe12Sn    E=-7.8091 eV/atom  SG=P1          E_hull=37.1 meV  run=current
#   Fe11Sn6     E=-6.7637 eV/atom  SG=P1          E_hull=87.7 meV  run=current
#   B13Sn2      E=-5.8719 eV/atom  SG=P1          E_hull=101.7 meV  run=current
#   FeSn13      E=-4.1632 eV/atom  SG=P-62m       E_hull=104.1 meV  run=current
#   BSn17       E=-3.9631 eV/atom  SG=P1          E_hull=113.5 meV  run=current
#   B11Fe4Sn2   E=-6.5772 eV/atom  SG=P1          E_hull=129.9 meV  run=current
#   B4Fe8Sn     E=-7.5332 eV/atom  SG=P1          E_hull=131.7 meV  run=current

# %% [markdown]
# ## View the Phase Diagram

# %%
# Plot the phase diagram (for ternary systems)
if result.phase_diagram is not None:
    try:
        fig = explorer.plot_phase_diagram(result, show_unstable=0.15)
        fig.show()
    except Exception as e:
        print(f"Phase diagram plotting not available: {e}")
else:
    print("No phase diagram available (need at least 2 valid candidates)")

# %% [markdown]
# ## Export Summary

# %%
# Export a JSON summary of the exploration
summary = explorer.export_summary(
    result,
    output_path=result.run_directory / "summary.json"
)

print("Summary exported!")
print(f"Hull entries: {summary['hull_entries']}")
# Out:
# Summary exported!
# Hull entries: [{'formula': 'B9Fe3Sn', 'energy_per_atom': -6.79293705866887, 'space_group': 'C2 (#5)', 'space_group_number': 5, 'space_group_symbol': 'C2'}, {'formula': 'B8Fe9', 'energy_per_atom': -7.784901338465073, 'space_group': 'C2/m (#12)', 'space_group_number': 12, 'space_group_symbol': 'C2/m'}, {'formula': 'B15Sn', 'energy_per_atom': -6.139235973358154, 'space_group': 'P1 (#1)', 'space_group_number': 1, 'space_group_symbol': 'P1'}]

# %% [markdown]
# ## Inspect Individual Structures

# %%
# Get the most stable structure
if result.hull_entries:
    best = result.hull_entries[0]
    print(f"Most stable: {best.formula}")
    print(f"Energy: {best.energy_per_atom:.4f} eV/atom")
    print(f"Space group: {best.space_group_symbol} (#{best.space_group_number})")
    print(f"CIF file: {best.cif_path}")
    
    # View with pymatviz if available
from pymatviz import StructureWidget
StructureWidget(best.structure)
# Out:
# Most stable: B9Fe3Sn
# Energy: -6.7929 eV/atom
# Space group: C2 (#5)
# CIF file: exploration_runs/exploration_B-Fe-Sn_20260105_150839/structures/B9Fe3Sn_C2.cif

# %% [markdown]
# ## Load a Previous Run
#
# You can reload a previous exploration from its directory:

# %%
# Load a previous run
# loaded = ChemistryExplorer.load_run("./exploration_runs/your_run_name")
# print(f"Loaded {loaded.num_candidates} candidates")

# %% [markdown]
# ## Query the SQLite Database Directly
#
# The SQLite database allows flexible querying:

# %%
import sqlite3
import pandas as pd

# Connect to the database
conn = sqlite3.connect(str(result.database_path))

# Query all candidates
df = pd.read_sql_query("""
    SELECT formula, energy_per_atom, space_group_symbol, 
           e_above_hull, is_on_hull, is_valid
    FROM candidates
    WHERE is_valid = 1
    ORDER BY e_above_hull ASC
""", conn)

print("All valid candidates:")
df
# Out:
# All valid candidates:
#       formula  energy_per_atom space_group_symbol  e_above_hull  is_on_hull  \
# 0           B        -6.034542               Cmmm           NaN           0
# 1          Fe        -8.435699              Im-3m           NaN           0
# 2          Sn        -3.946685              Fm-3m           NaN           0
# 3     B9Fe3Sn        -6.792937                 C2      0.000000           1
# 4       B8Fe9        -7.784901               C2/m      0.000000           1
# ..        ...              ...                ...           ...         ...
# 102    Fe17Sn        -6.327442             P6/mmm      1.858867           0
# 103   Fe17Sn2        -6.094091             P6/mmm      1.869080           0
# 104  B6Fe5Sn5        -4.148744                 P1      2.297677           0
# 105   B5Fe5Sn        -4.749363                 P1      2.614382           0
# 106    B14Fe3        -0.875503               P622      5.742492           0
#
#      is_valid
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 102         1
# 103         1
# 104         1
# 105         1
# 106         1
#
# [107 rows x 6 columns]
